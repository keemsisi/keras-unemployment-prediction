# %%
#example of making predictions for a regression problem
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split


datasets  =  pd.read_csv('dataset_new.csv')
#reshaping the network layer to have a shape of (1,None)
x_input_layer = datasets.Year.values.reshape(20,1)
y_output = datasets.drop(['Year'] ,  axis=1)

x_train , x_test , y_train , y_test = train_test_split (x_input_layer,y_output,test_size = 0.30, random_state =42)




# generate regression dataset
#X, y = make_regression(n_samples=100, n_features=2, noise=0.1, random_state=1)
scalarX, scalarY = MinMaxScaler(), MinMaxScaler()

scalarX.fit(x_input_layer)

scalarY.fit(y_output)

X = scalarX.transform(x_input_layer)
y = scalarY.transform(y_output)





# define and fit the final model
model = Sequential()
model.add(Dense(10, input_shape=(1,), activation='relu', kernel_initializer="uniform"))
model.add(Dense(10, activation='relu' , kernel_initializer='uniform'))
model.add(Dense(10, activation='relu' , kernel_initializer='uniform'))
model.add(Dense(10, activation='relu' , kernel_initializer='uniform'))

model.add(Dense(3, activation='linear'))


model.compile(loss='mse', optimizer='adam' ,metrics=['accuracy'])
model.fit(x_train, y_train, epochs=1000, verbose=1)


# new instances where we do not know the answer
Xnew, a = make_regression(n_samples=3, n_features=2, noise=0.1, random_state=1)
Xnew = scalarX.transform(Xnew)


# make a prediction
#ynew = model.predict(Xnew)
# show the inputs and predicted outputs

print(x_test)
model.predict(x_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch 1/1000
# 14/14 [==============================] - 0s 20ms/step - loss: 1123.6819 - acc: 0.0714
# Epoch 2/1000
# 14/14 [==============================] - 0s 171us/step - loss: 1122.9757 - acc: 0.0714
# Epoch 3/1000
# 14/14 [==============================] - 0s 165us/step - loss: 1122.3741 - acc: 0.0714
# Epoch 4/1000
# 14/14 [==============================] - 0s 139us/step - loss: 1121.8477 - acc: 0.0714
# Epoch 5/1000
# 14/14 [==============================] - 0s 200us/step - loss: 1121.4205 - acc: 0.0714
# Epoch 6/1000
# 14/14 [==============================] - 0s 140us/step - loss: 1121.0203 - acc: 0.0714
# Epoch 7/1000
# 14/14 [==============================] - 0s 130us/step - loss: 1120.6166 - acc: 0.0714
# Epoch 8/1000
# ...
