# %%
# Output network visualization
import pandas as pd
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import LabelBinarizer , MultiLabelBinarizer
from sklearn.model_selection  import train_test_split
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import LinearRegression
from keras import Sequential
#from keras.layers.in

data = pd.read_csv("dataset_new.csv")

x = data.Year
print(x)

y =data.drop(['Year'] , axis=1)

y.values


#print(y.values.reshape(20,3))



x_train , x_test , y_train , y_test = train_test_split (x,y,test_size = 0.30, random_state =42)

classif = OneVsRestClassifier(estimator=SVC(gamma='scale',random_state=0))

#y = MultiLabelBinarizer().fit_transform(y)
#classif.fit(x.values.reshape(20,1) , y)



params = {'n_estimators': 1000, 'max_depth': 8, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}

#using gradient boosting resgressor to predict the rate, unmale, unfemale in Nigeria
dd = GradientBoostingRegressor(verbose=1, **params)
cd = MultiOutputRegressor(dd) ; 
model = cd.fit(x.values.reshape(20,1), y)





#predicted = cd.predict(x.values.reshape(20,1))


predicted = model.predict([[2020],[2005],[2007],[2030],[2012],[2040]])


print("PREDICTION == " , predicted)

#model  = Sequential()
#model.add(Dense(32, input_shape=(16,)))


#print(y_train.shape)
#print(y.values[:,1])


data.head(100)
# Out:
# 0     1996
# 1     1997
# 2     1998
# 3     1999
# 4     2000
# 5     2001
# 6     2002
# 7     2003
# 8     2004
# 9     2005
# 10    2006
# 11    2007
# 12    2010
# 13    2011
# 14    2012
# 15    2013
# 16    2014
# 17    2015
# 18    2016
# 19    2017
# Name: Year, dtype: int64
#       Iter       Train Loss   Remaining Time
#          1          75.3731            2.25s
#          2          73.8732            1.52s
#          3          72.4031            1.93s
#          4          70.9623            1.84s
#          5          69.5501            1.84s
#          6          68.1661            1.69s
#          7          66.8096            1.57s
#          8          65.4801            1.60s
#          9          64.1770            1.54s
#         10          62.8999            1.45s
#         20          51.4463            0.87s
#         30          42.0782            0.67s
#         40          34.4161            0.61s
#         50          28.1492            0.55s
#         60          23.0234            0.49s
#         70          18.8310            0.45s
#         80          15.4020            0.46s
#         90          12.5974            0.46s
#        100          10.3035            0.46s
#        200           1.3805            0.40s
#        300           0.1850            0.29s
#        400           0.0248            0.22s
#        500           0.0033            0.17s
#        600           0.0004            0.14s
#        700           0.0001            0.11s
#        800           0.0000            0.07s
#        900           0.0000            0.03s
#       1000           0.0000            0.00s
#       Iter       Train Loss   Remaining Time
#          1         540.6403            0.92s
#          2         529.8815            1.06s
#          3         519.3369            1.09s
#          4         509.0021            1.13s
#          5         498.8730            1.13s
#          6         488.9454            1.13s
#          7         479.2154            1.12s
#          8         469.6790            1.12s
#          9         460.3324            1.12s
#         10         451.1718            1.12s
#         20         369.0165            0.83s
#         30         301.8212            0.68s
#         40         246.8616            0.59s
#         50         201.9098            0.53s
#         60         165.1435            0.49s
#         70         135.0720            0.47s
#         80         110.4763            0.44s
#         90          90.3593            0.42s
#        100          73.9055            0.42s
#        200           9.9018            0.38s
#        300           1.3266            0.33s
#        400           0.1777            0.26s
#        500           0.0238            0.19s
#        600           0.0032            0.14s
#        700           0.0004            0.11s
#        800           0.0001            0.07s
#        900           0.0000            0.03s
#       1000           0.0000            0.00s
#       Iter       Train Loss   Remaining Time
#          1         230.6729            0.64s
#          2         226.0825            0.81s
#          3         221.5834            0.74s
#          4         217.1739            0.72s
#          5         212.8522            0.71s
#          6         208.6164            0.75s
#          7         204.4650            1.16s
#          8         200.3961            1.16s
#          9         196.4082            1.18s
#         10         192.4997            1.20s
#         20         157.4468            0.85s
#         30         128.7769            0.65s
#         40         105.3275            0.55s
#         50          86.1481            0.54s
#         60          70.4611            0.50s
#         70          57.6306            0.45s
#         80          47.1365            0.42s
#         90          38.5533            0.40s
#        100          31.5330            0.38s
#        200           4.2248            0.25s
#        300           0.5660            0.20s
#        400           0.0758            0.16s
#        500           0.0102            0.13s
#        600           0.0014            0.10s
#        700           0.0002            0.08s
#        800           0.0000            0.06s
#        900           0.0000            0.03s
#       1000           0.0000            0.00s
# PREDICTION ==  [[ 14.20008613  16.50078784  21.20029019]
#  [ 11.90064439  56.49929251  43.49936962]
#  [ 12.69994982  56.49929251  43.49936962]
#  [ 14.20008613  16.50078784  21.20029019]
#  [ 27.39924013   9.90084952  11.20093039]
#  [ 14.20008613  16.50078784  21.20029019]]
#     Year  rate  unmale  unfemale
# 0   1996   3.8    59.0      40.8
# 1   1997   3.2    64.4      35.6
# 2   1998   3.2    56.1      43.9
# 3   1999   8.2    53.8      46.2
# 4   2000  13.1    54.5      45.5
# 5   2001  13.6    56.4      43.6
# 6   2002  12.6    59.8      40.2
# 7   2003  14.8    55.5      44.5
# 8   2004  13.4    58.3      41.7
# 9   2005  11.9    56.5      43.5
# 10  2006  12.3    56.5      43.5
# 11  2007  12.7    56.5      43.5
# 12  2010  21.4     4.7       5.6
# 13  2011  23.9     5.9       6.1
# 14  2012  27.4     9.9      11.2
# 15  2013  24.7     8.4      11.7
# 16  2014  25.1     5.4       7.5
# 17  2015  29.2    15.7      22.0
# 18  2016  35.2    12.3      16.3
# 19  2017  14.2    16.5      21.2
